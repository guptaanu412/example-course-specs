# %% [markdown]
# ## Chapter 2: Regression

# %% [markdown]
# ### Exercise 3: Importing Data for Supervised Learning

# %% [markdown]
# ### Exercise 5: Linear Regression: Fit and Predict

# %% [markdown]
# #### Gapminder Data

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
gm = pd.read_csv('../datasets/gm_2008.csv')

# %%
gm_Xs = gm.dropna(how='any').drop(['Country', 'Year', 'Region', 'ID', 'child_mortality'], axis=1).values
gm_y = gm.dropna(how='any').child_mortality.values
gm_y = np.asarray(gm.dropna(how='any').child_mortality)
gm_names = gm.dropna(how='any').drop(['Country', 'Year', 'Region', 'ID', 'child_mortality'], axis=1).columns
np.shape(gm_Xs), np.shape(gm_y)
# Out:
# ((139, 8), (139,))

# %%
##Plot GDP as a function of fertility

_ = plt.scatter(gm_Xs[:,1],gm_y)
_ = plt.ylabel('GDP')
_ = plt.xlabel('Fertility')

# %%
#Linear Regression with one predictor variable
from sklearn import linear_model
gm_y = gm_y.reshape(-1, 1)
gm_Xb = gm_Xs[:,1].reshape(-1, 1)

# Create linear regression object
regr = linear_model.LinearRegression()
# Train the model using the training sets
regr.fit(gm_Xb, gm_y)
# Plot outputs
plt.scatter(gm_Xb, gm_y,  color='black')
plt.plot(gm_Xb, regr.predict(gm_Xb), color='blue',
         linewidth=3)
plt.show()

# %%
print(regr.score(gm_Xb, gm_y))

#Predict with 1 variable
print(regr.predict(3))
# Out:
# 0.81306962528
# [[ 44.96674856]]

# %%
from sklearn.metrics import mean_squared_error
# All Variables
# Create linear regression object
regr_all = linear_model.LinearRegression()
# Train the model using the training sets
regr_all.fit(gm_Xs, gm_y)
gm_mod = regr_all.predict(gm_Xs)

print(regr_all.score(gm_Xs, gm_y))
rmse = np.sqrt(mean_squared_error(gm_y, gm_mod))
print(rmse)
# Out:
# 0.890769024223
# 15.057594757

# %% [markdown]
# ### Exercise 6: Train/Test Split for Regression

# %%
from sklearn.model_selection import train_test_split
gm_X_train, gm_X_test, gm_y_train, gm_y_test = train_test_split(gm_Xs, gm_y, test_size = 0.3, random_state=42)

# Create linear regression object
regr_all = linear_model.LinearRegression()
# Train the model using the training sets
regr_all.fit(gm_X_train, gm_y_train)
gm_mod = regr_all.predict(gm_X_test)

print(regr_all.score(gm_X_test, gm_y_test))
rmse = np.sqrt(mean_squared_error(gm_y_test, gm_mod))
print(rmse)
# Out:
# 0.918285663801
# 12.7078775273

# %% [markdown]
# ### Exercise 8: 5 Fold CV

# %% [markdown]
# #### Gapminder Data

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score

regr = linear_model.LinearRegression()

# cross_val_predict returns an array of the same size as `y` where each entry
# is a prediction obtained by cross validation:
predicted = cross_val_predict(regr, gm_Xs, gm_y, cv=5)

plt.scatter(gm_y, predicted, color='black')
plt.plot([gm_y.min(), gm_y.max()], [gm_y.min(), gm_y.max()], color = 'blue', linewidth=3)
plt.ylabel('Predicted')
plt.xlabel('Measured')
plt.show();

# %%
cross_results = cross_val_score(regr, gm_Xs, gm_y, cv = 5)
for i in cross_results:
    print(i)
print("Average 5-Fold CV Score:" + str(np.mean(cross_results)))
# Out:
# 0.872621302208
# 0.845422455302
# 0.88433366485
# 0.848863933935
# 0.877140696921
# Average 5-Fold CV Score:0.865676410643

# %% [markdown]
# ### Exercise 9: 10 Fold CV Comparison

# %%
cross_results = cross_val_score(regr, gm_Xs, gm_y, cv = 10)
for i in cross_results:
    print(i)
print("Average 10-Fold CV Score:" + str(np.mean(cross_results)))
# Out:
# 0.818323556518
# 0.938519271177
# 0.811677616624
# 0.902619062227
# 0.611385651535
# 0.928790144362
# 0.900791559352
# 0.789856191387
# 0.905693519931
# 0.793965738102
# Average 10-Fold CV Score:0.840162231121

# %% [markdown]
# ## Regularization

# %% [markdown]
# ## Regularization: Gapminder Data

# %%
from sklearn.preprocessing import scale
gm_X = scale(gm_Xs)

# %%
from sklearn.linear_model import MultiTaskLasso, Lasso
las_coef = Lasso(alpha=0.3, normalize=True).fit(gm_X, gm_y).coef_
_ = plt.plot(range(len(gm_names)), las_coef)
_  = plt.xticks(range(len(gm_names)), gm_names.values, rotation=60)
plt.margins(0.02)

# %%
las = Lasso(alpha=1).fit(gm_X, gm_y)
model = las.predict(gm_X)
las.score(gm_X,gm_y)
# Out:
# 0.88641984027220122

# %%
las_coef
# Out:
# array([  0.        ,  22.92170817,   0.        ,  -0.        ,
#         -1.86990398,  -0.        ,   0.        , -16.88172238])

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge_coefs = Ridge(alpha=0.3, normalize=True).fit(gm_X, gm_y).coef_
_ = plt.plot(range(len(gm_names)), ridge_coefs)
_  = plt.xticks(range(len(gm_names)), gm_names.values, rotation=60)
plt.margins(0.02)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-8985d06b7aff> in <module>()
#       2
#       3 ridge_coefs = Ridge(alpha=0.3, normalize=True).fit(gm_X, gm_y).coef_
# ----> 4 _ = plt.plot(range(len(gm_names)), ridge_coefs)
#       5 _  = plt.xticks(range(len(gm_names)), gm_names.values, rotation=60)
#       6 plt.margins(0.02)
#
# //anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# //anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# ...

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1).fit(gm_X, gm_y)
model = ridge.predict(gm_X)
ridge.score(gm_X,gm_y)
# Out:
# 0.89070187074704388

# %%
ridge_coef
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1a441ec126cd> in <module>()
# ----> 1 ridge_coef
#
# NameError: name 'ridge_coef' is not defined

# %% [markdown]
# ## ElasticNet

# %%
from sklearn.linear_model import ElasticNet

elastic_net_coef = ElasticNet(alpha=0.3, normalize=True).fit(gm_X, gm_y).coef_
_ = plt.plot(range(len(gm_names)), elastic_net_coef)
_  = plt.xticks(range(len(gm_names)), gm_names.values, rotation=60)
plt.margins(0.02)

# %%
elastic_net = ElasticNet(alpha=1).fit(gm_X, gm_y)
model = elastic_net.predict(gm_X)
elastic_net.score(gm_X,gm_y)
# Out:
# 0.84372743927935845

# %%
elastic_net_coef
# Out:
# array([ 0.        ,  1.63372683,  0.62753034, -0.72242669, -1.303409  ,
#        -0.8823567 ,  0.98299894, -1.55103888])

# %%
##code closely modeled on this: http://scikit-learn.org/stable/auto_examples/exercises/plot_cv_diabetes.html#sphx-glr-auto-examples-exercises-plot-cv-diabetes-py
## so will need to edit
from sklearn.model_selection import cross_val_score
alphas = np.logspace(-4, 1, 30)

lasso = Lasso()

scores = list()
scores_std = list()

n_folds = 10

for alpha in alphas:
    lasso.alpha = alpha
    this_scores = cross_val_score(lasso, gm_X, gm_y, cv=n_folds, n_jobs=1)
    scores.append(np.mean(this_scores))
    scores_std.append(np.std(this_scores))

scores, scores_std = np.array(scores), np.array(scores_std)
plt.figure().set_size_inches(8, 6)
plt.semilogx(alphas, scores)

# plot error lines showing +/- std. errors of the scores
std_error = scores_std / np.sqrt(n_folds)

plt.semilogx(alphas, scores + std_error, 'b--')
plt.semilogx(alphas, scores - std_error, 'b--')

# alpha=0.2 controls the translucency of the fill color
plt.fill_between(alphas, scores + std_error, scores - std_error, alpha=0.2)

plt.ylabel('CV score +/- std error')
plt.xlabel('alpha')
plt.axhline(np.max(scores), linestyle='--', color='.5')
plt.xlim([alphas[0], alphas[-1]])
# Out:
# (0.0001, 10.0)
