# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# # ch2_1

# %% [markdown]
# ## Slide 3

# %%
## We'll import csv without all these args. Need to write csv...
boston = pd.read_csv('../datasets/boston.csv', header = None,
                 delim_whitespace = True, names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE',
                                                   'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'])

# %%
y = boston['MEDV'].values
X = boston.drop('MEDV', axis=1).values

print(type(y))
print(type(X))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Slide 4

# %%
_ = pd.scatter_matrix(boston, c=y, figsize=(25,25))

# %% [markdown]
# # ch2_2

# %% [markdown]
# ## Slide 1

# %%
X_room = X[:,5]

X_room.shape
# Out:
# (506,)

# %%
y = y.reshape(-1, 1)
X_room = X[:,5].reshape(-1, 1)

print(type(y), y.shape)
print(type(X_room), X_room.shape)
# Out:
# <class 'numpy.ndarray'> (506, 1)
# <class 'numpy.ndarray'> (506, 1)

# %%
_ = plt.scatter(X_room, y)
_ = plt.ylabel('Value of house /1000 ($)')
_ = plt.xlabel('Number of rooms')

# %% [markdown]
# ## Slide 2

# %%
# Linear regression with one predictor variable

from sklearn import linear_model
# Create linear regression object
regr = linear_model.LinearRegression()
# Train the model using the training sets
regr.fit(X_room, y)
# Plot outputs
plt.scatter(X_room, y,  color='black')
plt.plot(X_room, regr.predict(X_room), color='blue',
         linewidth=3)
plt.show()

# %% [markdown]
# ## Slides 6&7

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# Create linear regression object
regr_all = linear_model.LinearRegression()
# Train the model using the training sets
regr_all.fit(X_train, y_train)
y_pred = regr_all.predict(X_test)

regr_all.score(X_test, y_test)
# Out:
# 0.71122600574849071

# %% [markdown]
# # ch2_3

# %% [markdown]
# ## Slide 4

# %%
from sklearn.model_selection import cross_val_score

model = linear_model.LinearRegression()

cross_results = cross_val_score(model, X, y, cv = 5)
for i in cross_results:
    print(i)
print("Average 5-Fold CV Score:" + str(np.mean(cross_results)))
print("Standard Deviation of 5-Fold CV Score:" + str(np.std(cross_results)))
# Out:
# 0.63919993714
# 0.713866980383
# 0.587023436306
# 0.0792308054051
# -0.252941537255
# Average 5-Fold CV Score:0.353275924396
# Standard Deviation of 5-Fold CV Score:0.376567839333

# %% [markdown]
# # ch2_4

# %% [markdown]
# ## Slide 3

# %%
from sklearn.linear_model import Lasso

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

lasso = Lasso(alpha=0.1)

lasso.fit(X_train, y_train)

lasso_pred = lasso.predict(X_test)
lasso.score(X_test, y_test)
# Out:
# 0.69181479522830558

# %% [markdown]
# ## Slide 5

# %%
names = boston.drop('MEDV', axis=1).columns

lasso = Lasso(alpha=0.1)

lasso_coef = lasso.fit(X, y).coef_
_ = plt.plot(range(len(names)), lasso_coef)
_ = plt.xticks(range(len(names)), names, rotation=60)
_ = plt.ylabel('Coefficients')
plt.margins(0.02)
